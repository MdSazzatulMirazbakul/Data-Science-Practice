# %%
import os
Root_dir = os.getcwd()
Data_dir = os.path.join(Root_dir, "Data")
Dataset_path = os.path.join(Data_dir, "owid-energy-data.csv")
print(Root_dir)
print(Data_dir)
print(Dataset_path)
# Out:
# D:\Projects\Data_Science_Practice
# D:\Projects\Data_Science_Practice\Data
# D:\Projects\Data_Science_Practice\Data\owid-energy-data.csv
